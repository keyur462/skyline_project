# %%
# Core libraries
import numpy as np
import math
import os
import sys
import time

# Geometry
from shapely.geometry.polygon import Polygon
from shapely import affinity
from shapely.strtree import STRtree
import shapely.wkt

# Plotting (optional)
import matplotlib.pyplot as plt

# NMSLIB
import nmslib

# Multiprocessing (safe use)
from multiprocessing import Process

print(sys.version)
print("NMSLIB loaded successfully")
print("Available spaces example:", nmslib.init(space='WeightedJaccard'))
# Out:
# 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:20:11) [MSC v.1938 64 bit (AMD64)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 24
#      21 from multiprocessing import Process
#      23 print(sys.version)
# ---> 24 print("NMSLIB version:", nmslib.__version__)
#
# AttributeError: module 'nmslib' has no attribute '__version__'
